# %%
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())
groq_api_key = os.environ["GROQ_API_KEY"]

# %%
from langchain_groq import ChatGroq

chatModel = ChatGroq(model= "llama-3.3-70b-versatile")

# %%
messages = [
    ("system", "You are an helpful assistant."),
    ("human", "tell me about dswithbappy"),
]
response = chatModel.invoke(messages)
print(response.content)
# Out:
# I couldn't find any information on "dswithbappy." It's possible that it's a misspelling, a made-up word, or a term that is not widely recognized. Can you please provide more context or clarify what you mean by "dswithbappy"? I'll do my best to help you find the information you're looking for.

# %% [markdown]
# # Data Loader

# %%
# Txt data loading
from langchain_community.document_loaders import TextLoader

loader = TextLoader("data/be-good.txt")
loaded_data = loader.load()

# %%
loaded_data
# Out:
# [Document(metadata={'source': 'data/be-good.txt'}, page_content='Be good\n dswithbappy is a Teacher, who learn langchian.\n \nApril 2008(This essay is derived from a talk at the 2008 Startup School.)About a month after we started Y Combinator we came up with the\nphrase that became our motto: Make something people want.  We\'ve\nlearned a lot since then, but if I were choosing now that\'s still\nthe one I\'d pick.Another thing we tell founders is not to worry too much about the\nbusiness model, at least at first.  Not because making money is\nunimportant, but because it\'s so much easier than building something\ngreat.A couple weeks ago I realized that if you put those two ideas\ntogether, you get something surprising.  Make something people want.\nDon\'t worry too much about making money.  What you\'ve got is a\ndescription of a charity.When you get an unexpected result like this, it could either be a\nbug or a new discovery.  Either businesses aren\'t supposed to be\nlike charities
# ...

# %%
# CSV loader

from langchain_community.document_loaders import CSVLoader

loader = CSVLoader('./data/Street_Tree_List.csv')

loaded_data = loader.load()
loaded_data
# Out:
# [Document(metadata={'source': './data/Street_Tree_List.csv', 'row': 0}, page_content="TreeID: 168225\nqLegalStatus: DPW Maintained\nqSpecies: Arbutus 'Marina' :: Hybrid Strawberry Tree\nqAddress: 2547 Vallejo St\nSiteOrder: 1\nqSiteInfo: Sidewalk: Curb side : Cutout\nPlantType: Tree\nqCaretaker: Private\nqCareAssistant: \nPlantDate: \nDBH: 0\nPlotSize: Width 4ft\nPermitNotes: \nXCoord: 6001190.70767\nYCoord: 2117587.71154\nLatitude: 37.794558498932695\nLongitude: -122.43986908930563\nLocation: (37.794558498932695, -122.43986908930563)\nFire Prevention Districts: 13\nPolice Districts: 9\nSupervisor Districts: 1\nZip Codes: 57\nNeighborhoods (old): 27\nAnalysis Neighborhoods: 30"),
# ...

# %%
# %pip install "unstructured[html]"
# Out:
# ...
#   Using cached unstructured-0.18.15-py3-none-any.whl.metadata (24 kB)
# ...
# Using cached unstructured-0.18.15-py3-none-any.whl (1.8 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: unstructured 0.18.15 does not provide the extra 'html'
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# HTML loader
from langchain_community.document_loaders import UnstructuredHTMLLoader

loader = UnstructuredHTMLLoader('./data/100-startups.html')

loaded_data = loader.load()

# %%
loaded_data
# Out:
# [Document(metadata={'source': './data/100-startups.html'}, page_content='\n\nPosted on October 5, 2023\n\nAI Accelera\n\nNo Comments\n\nThe new book “100 AI Startups” by Julio Colomer presents 100 new Artificial Intelligence companies that have earned at least $500,000 in their first year of existence and are radically changing how things are done in over 30 sectors, including banking, insurance, health, education, legal, logistics, marketing, sales, customer service, and even in public administration.\n\nThese 100 startups from Silicon Valley show how the fastest-growing area among the new Artificial Intelligence companies are the new LLM Apps (LLM Apps), which are changing every sector and areas of the company.\n\nIt’s not science fiction. There are already startups with LLM Applications that have earned more than $500,000 before their first year of existence by doing this:\n\nImproving the effectiveness of surgeons.\n\nCustomer service in banks.\n\nTutoring for students.\n\nLegal 
# ...

# %%
# Pdf data

from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader('./data/5pages.pdf')

loaded_data = loader.load_and_split()

# %%
loaded_data
# Out:
# [Document(metadata={'producer': 'Acrobat Distiller 7.0.5 (Windows)', 'creator': 'PyPDF', 'creationdate': '2009-01-23T12:27:48-05:00', 'moddate': '2015-07-24T12:27:45-04:00', 'title': 'untitled', 'source': './data/5pages.pdf', 'total_pages': 4, 'page': 0, 'page_label': '1'}, page_content='Page 1 of 4 \nPDF Files \nScan – Create – Reduce File Size  \n \n \nIt is recommended that you purchase an Adobe Acrobat product that \nallows you to read, create and manipulate PDF documents.  Go to \nhttp://www.adobe.com/products/acrobat/matrix.html\n to compare \nAdobe products and features –Adobe Acrobat Standard is sufficient. \n \n \nScanning Documents \n \nYou should only have to scan documents that are not electronic, and \nwhen you are unable to create a PDF using PDFMaker or the Print \nCommand from the application you are using.   \n \nSignature Pages \nIf you have a document such as a CV that requires a signature on a \npage only print the page that requires the signature –printing the \n
# ...

# %%
loaded_data[0].page_content
# Out:
# 'Page 1 of 4 \nPDF Files \nScan – Create – Reduce File Size  \n \n \nIt is recommended that you purchase an Adobe Acrobat product that \nallows you to read, create and manipulate PDF documents.  Go to \nhttp://www.adobe.com/products/acrobat/matrix.html\n to compare \nAdobe products and features –Adobe Acrobat Standard is sufficient. \n \n \nScanning Documents \n \nYou should only have to scan documents that are not electronic, and \nwhen you are unable to create a PDF using PDFMaker or the Print \nCommand from the application you are using.   \n \nSignature Pages \nIf you have a document such as a CV that requires a signature on a \npage only print the page that requires the signature –printing the \nentire document and scanning it is not\n necessary or desired.  Once you \nsign and scan the signature page you can combine it with the original \ndocument using the Create PDF From Multiple Files feature. \n \nScanner Settings \nBefore scanning documents remember to make certain that th
# ...

# %%
# wikipedia data loader

from langchain_community.document_loaders import WikipediaLoader

loader = WikipediaLoader(query="tesla", load_max_docs=1)

loaded_data = loader.load()[0].page_content

# %%
messages = [
    ("system", "You are an helpful assistant."),    
    ("human", f"tell me about tesla {loaded_data}"),
]
response = chatModel.invoke(messages)
print(response.content)
# Out:
# Nikola Tesla was a true pioneer and visionary in the field of electrical engineering and physics. Born on July 10, 1856, in Smiljan, Croatia, which was then part of the Austrian Empire, Tesla's early life and education laid the foundation for his future achievements.
#
# **Early Life and Education**
#
# Tesla was born into an ethnic Serb family, with his father, Milutin Tesla, serving as a priest of the Eastern Orthodox Church. His mother, Georgina "Đuka" Mandić, was known for her talent in making home craft tools and mechanical appliances, as well as her ability to memorize Serbian epic poems. Tesla credited his mother's genetics and influence for his eidetic memory and creative abilities.
#
# Tesla attended primary school in Smiljan and later moved to Gospić, where he completed primary and middle school. In 1870, he moved to Karlovac to attend high school, where he excelled in his studies, particularly in mathematics and physics.
#
# **Career and Contributions**
#
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_template = ChatPromptTemplate.from_messages(
    [
        ("human", "Answer this {question}, here is some extra {context}"),
    ]
)

messages = chat_template.format_messages(
    name="Tesla",
    question="Tell me about tesla",
    context=loaded_data
)

# %%
response = chatModel.invoke(messages)

# %%
response.content
# Out:
# 'Nikola Tesla was a Serbian-American engineer, futurist, and inventor who made significant contributions to the design of the modern alternating current (AC) electricity supply system. He was born on July 10, 1856, in Smiljan, a village in the Austrian Empire (now Croatia), to an ethnic Serb family. His father, Milutin Tesla, was a priest of the Eastern Orthodox Church, and his mother, Georgina "Đuka" Mandić, was talented in making home craft tools and mechanical appliances.\n\nTesla\'s early education took place in Smiljan and Gospić, where he studied German, arithmetic, and religion. He later attended high school in Karlovac, and in 1870, he began studying engineering and physics, although he did not receive a degree. Tesla gained practical experience in the early 1880s working in telephony and at Continental Edison in the new electric power industry.\n\nIn 1884, Tesla immigrated to the United States, where he became a naturalized citizen. He worked for a short time at the Edison M
# ...

# %% [markdown]
# ### sending all files as input tokens to an LLM  has some negative things
#
# Drawbacks:
# 1) Input limit issues: models have finite context windows. Feeding all files can exceed the limit, causing truncation or the need for complex chunking and state management, which risks losing important context and increases engineering complexity and latency.
# 2) Cost: token-based billing and compute scale with input size. Large inputs drive up inference cost and slow throughput, making the approach expensive and inefficient for frequent or large-scale use.
#
# Mitigations (brief): summarize or filter inputs, use embedding + retrieval to send only relevant passages, or apply hierarchical chunking and caching to reduce token usage and cost.

# %% [markdown]
# ## solutions
#
# RAG - Retriver Augmented Genrateions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Note
#
# * If the loaded data (txt/pdf) is **smaller than the model’s input limit**, it can be sent directly without issues.
# * If the data is **larger than the input limit**, we must use **RAG (Retrieval-Augmented Generation)** to split, embed, and retrieve only the relevant parts for the model.
#
# ---

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("data/sr.txt")
loaded_data = loader.load()

# %%
# If you want to ask the model about Shakil using that document as context:
messages = [
	("system", "You are a helpful assistant."),
	("human", f"Tell me about Shakil. Here is some context:\n\n{loaded_data[0].page_content}"),
]
response = chatModel.invoke(messages)
print(response.content)
# Out:
# Based on the context you provided, it seems that Shakil is a person who has a somewhat indifferent or neutral outlook on life, as indicated by the phrase "Shakil loves noting" (which I assume is a typo and you meant "nothing"). This suggests that Shakil may not have strong passions or interests in general.
#
# However, it's also mentioned that "sometimes he likes swimming", which implies that Shakil may have a occasional interest in swimming. This could be a hobby or activity that he enjoys, even if it's not a consistent passion.
#
# Overall, Shakil appears to be a person with a laid-back or casual approach to life, with a possible interest in swimming as a occasional activity. Is there anything specific you'd like to know about Shakil or would you like me to elaborate on this further?
