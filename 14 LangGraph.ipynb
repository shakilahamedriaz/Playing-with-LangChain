# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# tools and knowledge base:
#
# - llm will decide it will use Knowledge base or Tools.

# %% [markdown]
# # Connect your LLM to the Web
# - using: tavily( serach api)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # another serach api called " Serp Api " for google search api

# %% [markdown]
# ![image.png](attachment:image.png)
